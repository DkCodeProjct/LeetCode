# %% [markdown]
# ![homework-in-china-how-tall-table-problem.png](data:image/png;base64,...)

# %% [markdown]
# ### So i Stumble upon in insta,, and then so this puzzule,,
#    + and it immediatly click me,, Oh, isn't coding is the same..
#    + like in coding, we saw a problem that we never seen before and going to solve it..
#    + **Its the Logic that we Need to Code, and How we gonna Aproch a Probel**

# %%
# // First Attempt

## Find How tall cat
catToTurtle = 170
turtleToCat = 130
cat = catToTurtle - turtleToCat
cat
# Out:
# 40

# %%
# After read the doc, got hint to make equation

cat + table - turtle = 170
turtle + tabe - cat = 130

# so cat and turtle cancle, and we got 2*table,
2(table) = 300

# use algabra t0 find table
table = 300/2
table
# Out:
# 150.0
